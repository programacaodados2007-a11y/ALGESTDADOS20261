# %% [markdown]
# <a href="https://colab.research.google.com/github/programacaodados2007-a11y/ALGESTDADOS20261/blob/main/Exerc%C3%ADcios%20de%20fixa%C3%A7%C3%A3o/Exerc%C3%ADcio_12_03_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Declare duas variáveis a = 15 e b = 4. Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.
a = 15
b = 4
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)

# %%
# 2. Um professor deseja dividir 37 alunos em grupos iguais de 5. Usando operadores aritméticos, descubra:
# quantos grupos completos serão formados
# quantos alunos sobrarão

grupo = 37
print(f'A quantidade de grupos de 5 pessoas serão de {grupo // 5}. E o resto dessa divisão é {grupo % 5}')
# Out:
# A quantidade de grupos de 5 pessoas serão de 7. E o resto dessa divisão é 2

# %%
# 3. Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem: A área do retângulo é: X
b = 8.5
h = 3.2
print(f'A área do retângulo é: {b * h}')
# Out:
# A área do retângulo é: 27.200000000000003

# %%
# 4. Dado o valor:
segundos = 9875
# Use // e % para converter esse valor em horas, minutos e segundos. Exemplo de saída: 2h 44min 35seg

h = segundos // 3600
resto = segundos % 3600

minutos = resto // 60
seg = resto % 60

print(f'{h}h {minutos}min {seg}seg')

# %%
# 5. Calcule: 2 ** 10 Explique com um comentário no código o que essa operação representa. Depois calcule a raiz quadrada de 144 usando potenciação.

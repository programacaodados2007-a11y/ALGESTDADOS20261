# %% [markdown]
# <a href="https://colab.research.google.com/github/programacaodados2007-a11y/ALGESTDADOS20261/blob/main/Exerc%C3%ADcios%20de%20fixa%C3%A7%C3%A3o/Exerc%C3%ADcio_12_03_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Declare duas variáveis a = 15 e b = 4. Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.
a = 15
b = 4
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)

# %%
# 2. Um professor deseja dividir 37 alunos em grupos iguais de 5. Usando operadores aritméticos, descubra:
# quantos grupos completos serão formados
# quantos alunos sobrarão

grupo = 37
print(f'A quantidade de grupos de 5 pessoas serão de {grupo // 5}. E o resto dessa divisão é {grupo % 5}')
# Out:
# A quantidade de grupos de 5 pessoas serão de 7. E o resto dessa divisão é 2

# %%
# 3. Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem: A área do retângulo é: X
b = 8.5
h = 3.2
print(f'A área do retângulo é: {b * h}')
# Out:
# A área do retângulo é: 27.200000000000003

# %%
# 4. Dado o valor:
segundos = 9875
# Use // e % para converter esse valor em horas, minutos e segundos. Exemplo de saída: 2h 44min 35seg

h = segundos // 3600
resto = segundos % 3600

minutos = resto // 60
seg = resto % 60

print(f'{h}h {minutos}min {seg}seg')

# %%
# 5. Calcule: 2 ** 10 Explique com um comentário no código o que essa operação representa. Depois calcule a raiz quadrada de 144 usando potenciação.
a = 2
b = 10
print(f'Essa opéração representa a pontênciação do número 2 elevado a 10 que o resultado é {a ** b}')

raiz = 144 ** 0.5
print(f'A raiz qaudrada de 144 é {raiz}')

# %%
# 6. Crie uma variável:temperatura = 38.5. Use operadores relacionais para verificar: se a temperatura é maior que 37.5, se a temperatura é igual a 36.5, se a temperatura é diferente de 40.0.
temperatura = 38.5
print(temperatura > 37.5)
print(temperatura == 36.5)
print(temperatura != 40)

# %%
# 7. Dados:
x = 10
y = 10
# Preveja o resultado antes de executar e depois confirme no Python:
x == y # True
x != y # False
x >= y # # True
x <= y + 1 # True

print(x == y)
print(x != y)
print(x >= y)
print(x <= y + 1)

# %%
# 8. Um aluno tirou nota 6.5. Usando operadores relacionais, verifique se ele:
# foi aprovado (>= 7.0)
# está em recuperação (>= 5.0 e < 7.0)
# foi reprovado (< 5.0)
# Use print() para exibir cada verificação.

nota = 6.5
print(f'Esse aluno foi aprovado? {nota >= 7.0}')
print(f'Esse aluno se encontra em recuperação? {nota >= 5.0 and nota < 7.0}')
print(f'Esse aluno foi reprovado? {nota < 5.0}')

# %%
# 9. Declare: a = 5 e b = "5". Compare: a == b. Explique o resultado com um comentário no código.
a = 5
b = "5"
print(f'{a == b}. O código deu False pelo fato de a variaavél "a" receber o número 5, porém a variavél "b" recebe o texto 5. com isso, a igualdade, a == b, não se satisfaz')
# Out:
# False. O código deu False pelo fato de a variaavél "a" receber o número 5, porém a variavél "b" recebe o texto 5. com isso, a igualdade, a == b, não se satisfaz

# %%
# 10. Crie um programa com: preco = 49.90. Verifique se o produto está dentro do orçamento de R$ 50,00 usando <=.
preco = 49.90
print(49.90 <= 50.00)
# Out:
# True

# %%
# 11. Uma pessoa pode votar se tiver 16 anos ou mais. idade = 15. Use operadores lógicos para verificar se ela não pode votar. Depois teste com: idade = 18
id1 = 15
print(id1 >= 16)

id2 = 18
print(id2 >= 18)
# Out:
# False
# True

# %%
# 12. Um empréstimo é aprovado se: renda >= 2000, score >= 700 Teste pelo menos três combinações diferentes usando and.

# Pessoa 1
renda = 2500
score = 750
print(f'Pessoa 1 - Empréstimo Aprovado: {renda >= 2000 and score >= 700}')

# Pessoa 2
renda = 1000
score = 950
print(f'Pessoa 2 - Empréstimo Aprovado: {renda >= 2000 and score >= 700}')

# Pessoa 3
renda = 10000
score = 420
print(f'Pessoa 3 - Emprésimo Aprovado: {renda >= 2000 and score >= 700}')

# %%
# 13. Um sistema libera acesso se o usuário for administrador ou tiver nível de acesso ≥ 3. is_admin = False, nivel_acesso = 4. Use o operador or.
is_admin = False
nivel_acesso = int(input('Qual o seu nível de acesso? '))
print(is_admin or nivel_acesso >= 3)

# %%
# 14. Dado: chovendo = True. Use not para verificar se não está chovendo. Depois combine com uma verificação de temperatura maior que 25.
chovendo = True
print(not chovendo)

temperatura = float(input('Qual a temperatura de sua cidade agora? '))
print(not chovendo or temperatura > 25)

# %%
# 15. Monte manualmente a tabela-verdade do operador and:
print(True and True)
print(True and False)
print(False and True)
print(False and False)

# %%
# 16. Calcule manualmente antes de executar:
print(5 + 2 * 3)
print((5 + 2) * 3)
print(2 ** 3 ** 2)
print(10 - 4 / 2 + 1)
# Explique a ordem de execução nos comentários.
# Out:
# 11
# 21
# 512
# 9.0

# %% [markdown]
# <a href="https://colab.research.google.com/github/programacaodados2007-a11y/ALGESTDADOS20261/blob/main/Exerc%C3%ADcios%20de%20fixa%C3%A7%C3%A3o/Exerc%C3%ADcio_3_19___03___2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Peça um número inteiro ao usuário. Se o número for maior que zero, exiba a mensagem "O número é positivo!".
num = int(input("Digte um número: "))

if num > 0:
    print('O número positivo!')
else:
    print("O seu número não é um número positivo!")
# Out:
# Digte um número: 36
# O número positivo!

# %%
# 2. Leia a idade do usuário. Se for maior ou igual a 18, exiba "Maior de idade", caso contrário, exiba "Menor de idade".
idade = int(input('Digite sua idade: '))

if idade >= 18:
    print('Maior de idade!')
else:
    print('Menor de Idade!')

# %%
# 3. Solicite um número inteiro. Verifique se ele é par (divisível por 2) e exiba uma mensagem informando o resultado.
numero = int(input('Digite seu número: '))
if numero % 2 == 0:
    print("O seu número é Par!")
else:
    print("O seu número não é Par!")
# Out:
# Digite seu número: 2
# O seu número é Par!

# %%
# 4. Defina uma senha fixa no código (ex: "python123"). Peça a senha ao usuário. Se bater, exiba "Acesso permitido", senão "Acesso negado".
senha = input("Digite sua senha: ")
if senha == "python123":
    print("Acesso permitido")
else:
    print("Acesso negado")
# Out:
# Digite sua senha: 215552
# Acesso negado

# %%
# 5. Leia a temperatura em graus Celsius. Se for maior que 30, exiba "Está quente hoje!". Caso contrário, exiba "Temperatura agradável."
temperatura =  float(input('Qual temperatura hoje: '))
if temperatura > 30:
    print("Está quente hoje!")
else:
    print("Temperatura agradável")
# Out:
# Qual temperatura hoje: 25
# Temperatura agradável

# %%
# 6. Defina um saldo fixo (ex: 100.0). Peça ao usuário um valor para saque. Se o valor for menor ou igual ao saldo, exiba "Saque realizado!", caso contrário, "Saldo insuficiente."
saldo = 120.0
saque = float(input('Qual valor você quer sacar?'))
if saque <= saldo:
    print('Saldo realizado!')
else:
    print("Saldo insuficiente!")
# Out:
# Qual valor você quer sacar?124
# Saldo insuficiente!

# %%
# 7. Leia a nota de um aluno (0 a 10). Se a nota for maior ou igual a 5, exiba "Aprovado". Senão, exiba "Reprovado".
nota = float(input('Qual a sua nota? '))
if nota >= 5:
    print('Aprovado')
else:
    print('Reprovado')
# Out:
# Qual a sua nota? 10
# Aprovado

# %%
# 8. Peça um número ao usuário. Exiba se o número é zero ou diferente de zero usando if/else.
numero = int(input('Digite um número: '))
if numero == 0:
    print('O número é igual a zero!')
else:
    print('O número é diferente de zero!')
# Out:
# Digite um número: 32
# O número é diferente de zero!

# %%
# 9. Peça um número ao usuário. Sem usar == 0, use o próprio valor como condição no if para exibir "O número é falsy (zero)" ou "O número é truthy (diferente de zero)".
numero = bool(int(input('Digite seu número: ')))
if numero is True:
    print("O número e truthy (diferente de zero)")
else:
    print("O número é falsy (zero)")
# Out:
# Digite seu número: 12
# O número e truthy (diferente de zero)

# %%
# 10. Peça ao usuário para digitar a cor do semáforo ("verde" ou outra cor). Se for "verde", exiba "Pode avançar!", caso contrário, "Pare!".
cor = input('Digite a cor do semáforo: ')
if cor.upper() == "VERDE":
    print("Pode avançar!")
else:
    print("Pare!")

# %%
# 11. Leia o nome do usuário. Se o nome for uma string vazia (falsy), exiba "Nenhum nome digitado.", caso contrário, exiba "Olá, [nome]!" usando f-string.
nome = input("Digite seu nome: ")

if bool (nome) is False:
    print("Nenhum nome digitado.")
else:
    print(f"Olá, {nome}")
# Out:
# Digite seu nome: Eduardo
# Olá, Eduardo

# %%
# 12. Leia dois números inteiros. Exiba qual deles é o maior. Se forem iguais, exiba "Os números são iguais."
n1 = int(input("Digite o primeiro número: "))
n2 = int(input("Digite o segundo número:"))

if n1 > n2:
    print(f"O maior número é {n1}")
elif n2 > n1:
    print(f'O maior número é {n2}')
else:
    print("Os número são iguais.")
# Out:
# Digite o primeiro número: 15
# Digite o segundo número:17
# O maior número é 17

# %%
# 13. Pergunte ao usuário "Está chovendo? (sim/nao)". Se a resposta for "sim", exiba "Leve o guarda-chuva!", senão, "Não precisa de guarda-chuva."
resposta =  input("Está chovendo? (sim/nao)")
if resposta.upper() == 'SIM':
    print("Leve o guarda-chuva!")
else:
    print("Não precisa de guarda-chuva.")

# %%
#14 - Pergunte se hoje é o aniversário do usuário (resposta: "sim" ou "nao"). Se sim, exiba "Parabéns! Você tem 20% de desconto." Senão, "Sem desconto hoje."
resposta =  input("hoje é o seu aniversário? (sim/nao)")
if resposta.upper() ==  'SIM':
    print("Parabéns! Você tem 20% de desconto.")
else:
    print("Sem desconto hoje.")

# %%
#15 - Crie um programa que leia um número. Dentro do bloco if, exiba duas mensagens diferentes (duas linhas de print). Fora do if, exiba uma terceira mensagem que sempre aparece. Demonstre o uso correto da indentação com 4 espaços.
num = int(input('Digite um número: '))
if num:
    print('É um número')
    print('Identação é obrigação!')
print('This is the end!')
